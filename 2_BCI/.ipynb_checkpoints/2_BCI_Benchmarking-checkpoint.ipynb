# %% [markdown]
# # Demo 1 - Comparing BCI pipelines with MOABB - Code based on this [tutorial](http://moabb.neurotechx.com/docs/auto_examples/advanced_examples/plot_statistical_analysis.html#sphx-glr-download-auto-examples-advanced-examples-plot-statistical-analysis-py)

# %%
import matplotlib.pyplot as plt
from mne.decoding import CSP
from pyriemann.estimation import Covariances
from pyriemann.tangentspace import TangentSpace
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.svm import SVC

import moabb
from moabb import benchmark, set_log_level
from moabb.analysis.plotting import score_plot
import moabb.analysis.plotting as moabb_plt
from moabb.analysis.meta_analysis import (  # noqa: E501
    compute_dataset_statistics,
    find_significant_differences,
)
from moabb.datasets import BNCI2014001, Zhou2016, Cho2017
from moabb.evaluations import CrossSessionEvaluation
from moabb.paradigms import LeftRightImagery

import seaborn as sns

moabb.set_log_level("info")
print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
# pipelines to be compared

pipelines = {}

param_svm = {"kernel": ("linear", "rbf"), "C": [0.1, 1, 10]}
step_csp_svm = [
    ("cov", Covariances(estimator="lwf")),
    ("csp", CSP(6)),
    ("optsvm", GridSearchCV(SVC(), param_svm, cv=3)),
]
pipelines["CSP+optSVM"] = Pipeline(steps=step_csp_svm)


pipelines["CSP+LDA"] = make_pipeline(CSP(n_components=8), LDA())

pipelines["RG+LR"] = make_pipeline(Covariances(), TangentSpace(), LogisticRegression())

pipelines["CSP+LR"] = make_pipeline(CSP(n_components=8), LogisticRegression())

pipelines["RG+LDA"] = make_pipeline(Covariances(), TangentSpace(), LDA())

# %%
# evaluation on one dataset

paradigm = LeftRightImagery()
dataset = BNCI2014001()
dataset.subject_list = dataset.subject_list[:4]
datasets = [dataset]
overwrite = True  # set to False if we want to use cached results
evaluation = CrossSessionEvaluation(
    paradigm=paradigm, datasets=datasets, suffix="stats", overwrite=overwrite
)

results = evaluation.process(pipelines)
# Out:
# 2023-11-07 15:24:27,415 INFO MainThread moabb.evaluations.base Processing dataset: 001-2014
# 001-2014-CrossSession:   0%|                                                                                                                   | 0/4 [00:00<?, ?it/s]2023-11-07 15:24:30,257 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 1 | session_E: Score 0.856
# 2023-11-07 15:24:30,433 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 1 | session_T: Score 0.768
# 2023-11-07 15:24:30,912 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 1 | session_E: Score 0.955
# 2023-11-07 15:24:31,386 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 1 | session_T: Score 0.932
# 2023-11-07 15:24:31,604 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 1 | session_E: Score 0.963
# 2023-11-07 15:24:31,768 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 1 | session_T: Score 0.950
# 2023-11-07 15:24:32,234 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 1 | session_E: Score 0.969
# 2023-11-07 15:24:32,707 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 1 | session_T: Score 0.954
# 2023-11-07 15:24:32,932 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 1 | session_E: Score 0.878
# 2023-11-07 15:24:33,127 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 1 | session_T: Score 0.861
# 001-2014-CrossSession:  25%|██████████████████████████▊                                                                                | 1/4 [00:05<00:17,  5.71s/it]2023-11-07 15:24:35,836 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 2 | session_E: Score 0.403
# 2023-11-07 15:24:36,015 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 2 | session_T: Score 0.490
# 2023-11-07 15:24:36,491 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 2 | session_E: Score 0.646
# 2023-11-07 15:24:36,963 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 2 | session_T: Score 0.527
# 2023-11-07 15:24:37,129 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 2 | session_E: Score 0.586
# 2023-11-07 15:24:37,294 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 2 | session_T: Score 0.575
# 2023-11-07 15:24:37,759 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 2 | session_E: Score 0.629
# 2023-11-07 15:24:38,233 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 2 | session_T: Score 0.537
# 2023-11-07 15:24:38,426 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 2 | session_E: Score 0.470
# 2023-11-07 15:24:38,616 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 2 | session_T: Score 0.513
# 001-2014-CrossSession:  50%|█████████████████████████████████████████████████████▌                                                     | 2/4 [00:11<00:11,  5.58s/it]2023-11-07 15:24:41,246 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 3 | session_E: Score 0.854
# 2023-11-07 15:24:41,418 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 3 | session_T: Score 0.923
# 2023-11-07 15:24:41,889 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 3 | session_E: Score 0.996
# 2023-11-07 15:24:42,363 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 3 | session_T: Score 0.994
# 2023-11-07 15:24:42,529 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 3 | session_E: Score 0.999
# 2023-11-07 15:24:42,694 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 3 | session_T: Score 0.999
# 2023-11-07 15:24:43,168 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 3 | session_E: Score 0.997
# 2023-11-07 15:24:43,644 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 3 | session_T: Score 0.994
# 2023-11-07 15:24:43,833 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 3 | session_E: Score 0.973
# 2023-11-07 15:24:44,023 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 3 | session_T: Score 0.966
# 001-2014-CrossSession:  75%|████████████████████████████████████████████████████████████████████████████████▎                          | 3/4 [00:16<00:05,  5.50s/it]2023-11-07 15:24:46,534 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 4 | session_E: Score 0.608
# 2023-11-07 15:24:46,709 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 4 | session_T: Score 0.639
# 2023-11-07 15:24:47,186 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 4 | session_E: Score 0.829
# 2023-11-07 15:24:47,637 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 4 | session_T: Score 0.829
# 2023-11-07 15:24:47,809 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 4 | session_E: Score 0.877
# 2023-11-07 15:24:47,968 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 4 | session_T: Score 0.858
# 2023-11-07 15:24:48,447 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 4 | session_E: Score 0.837
# 2023-11-07 15:24:48,912 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 4 | session_T: Score 0.835
# 2023-11-07 15:24:49,101 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 4 | session_E: Score 0.721
# 2023-11-07 15:24:49,281 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 4 | session_T: Score 0.690
# 001-2014-CrossSession: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:21<00:00,  5.47s/it]

# %%
# plot comparison
fig = moabb_plt.score_plot(results)
plt.show()
# Out:
# 2023-11-07 15:24:58,944 WARNING MainThread moabb.analysis.plotting Dataset names are too similar, turning off name shortening
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/analysis/plotting.py:59: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sea.stripplot(

# %%
fig = moabb_plt.paired_plot(results, "CSP+LDA", "RG+LDA")
plt.show()

# %%
# plot statistical comparison
stats = compute_dataset_statistics(results)
P, T = find_significant_differences(stats)

fig = moabb_plt.meta_analysis_plot(stats, "CSP+LDA", "RG+LDA")
plt.show()

# %%
moabb_plt.summary_plot(P, T)
plt.show()

# %% [markdown]
# # Demo 2 - Benchmarking with different datasets

# %%
paradigm = LeftRightImagery()
subj = [1, 2, 3]
datasets = [BNCI2014001(), Zhou2016()]
for d in datasets:
    d.subject_list = subj

overwrite = True  # set to False if we want to use cached results
evaluation = CrossSessionEvaluation(
    paradigm=paradigm, datasets=datasets, suffix="stats", overwrite=overwrite
)

results = evaluation.process(pipelines)
# Out:
# 2023-11-07 15:25:13,751 INFO MainThread moabb.evaluations.base Processing dataset: 001-2014
# 001-2014-CrossSession:   0%|                                                                                                                   | 0/3 [00:00<?, ?it/s]2023-11-07 15:25:16,468 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 1 | session_E: Score 0.856
# 2023-11-07 15:25:16,644 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 1 | session_T: Score 0.768
# 2023-11-07 15:25:17,127 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 1 | session_E: Score 0.955
# 2023-11-07 15:25:17,600 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 1 | session_T: Score 0.932
# 2023-11-07 15:25:17,764 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 1 | session_E: Score 0.963
# 2023-11-07 15:25:17,928 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 1 | session_T: Score 0.950
# 2023-11-07 15:25:18,393 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 1 | session_E: Score 0.969
# 2023-11-07 15:25:18,864 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 1 | session_T: Score 0.954
# 2023-11-07 15:25:19,056 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 1 | session_E: Score 0.878
# 2023-11-07 15:25:19,248 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 1 | session_T: Score 0.861
# 001-2014-CrossSession:  33%|███████████████████████████████████▋                                                                       | 1/3 [00:05<00:10,  5.50s/it]2023-11-07 15:25:21,906 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 2 | session_E: Score 0.403
# 2023-11-07 15:25:22,083 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 2 | session_T: Score 0.490
# 2023-11-07 15:25:22,554 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 2 | session_E: Score 0.646
# 2023-11-07 15:25:23,009 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 2 | session_T: Score 0.527
# 2023-11-07 15:25:23,179 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 2 | session_E: Score 0.586
# 2023-11-07 15:25:23,342 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 2 | session_T: Score 0.575
# 2023-11-07 15:25:23,808 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 2 | session_E: Score 0.629
# 2023-11-07 15:25:24,295 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 2 | session_T: Score 0.537
# 2023-11-07 15:25:24,485 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 2 | session_E: Score 0.470
# 2023-11-07 15:25:24,675 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 2 | session_T: Score 0.513
# 001-2014-CrossSession:  67%|███████████████████████████████████████████████████████████████████████▎                                   | 2/3 [00:10<00:05,  5.46s/it]2023-11-07 15:25:27,336 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 3 | session_E: Score 0.854
# 2023-11-07 15:25:27,507 INFO MainThread moabb.evaluations.base CSP+optSVM | 001-2014 | 3 | session_T: Score 0.923
# 2023-11-07 15:25:27,986 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 3 | session_E: Score 0.996
# 2023-11-07 15:25:28,459 INFO MainThread moabb.evaluations.base CSP+LDA | 001-2014 | 3 | session_T: Score 0.994
# 2023-11-07 15:25:28,622 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 3 | session_E: Score 0.999
# 2023-11-07 15:25:28,784 INFO MainThread moabb.evaluations.base RG+LR | 001-2014 | 3 | session_T: Score 0.999
# 2023-11-07 15:25:29,256 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 3 | session_E: Score 0.997
# 2023-11-07 15:25:29,711 INFO MainThread moabb.evaluations.base CSP+LR | 001-2014 | 3 | session_T: Score 0.994
# 2023-11-07 15:25:29,901 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 3 | session_E: Score 0.973
# 2023-11-07 15:25:30,090 INFO MainThread moabb.evaluations.base RG+LDA | 001-2014 | 3 | session_T: Score 0.966
# 001-2014-CrossSession: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:16<00:00,  5.45s/it]
# 2023-11-07 15:25:30,095 INFO MainThread moabb.evaluations.base Processing dataset: Zhou 2016
# Zhou 2016-CrossSession:   0%|                                                                                                                  | 0/3 [00:00<?, ?it/s]/opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# 2023-11-07 15:25:32,546 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 1 | session_0: Score 0.568
# 2023-11-07 15:25:32,714 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 1 | session_1: Score 0.930
# 2023-11-07 15:25:32,894 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 1 | session_2: Score 0.624
# 2023-11-07 15:25:33,393 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 1 | session_0: Score 0.861
# 2023-11-07 15:25:33,922 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 1 | session_1: Score 0.944
# 2023-11-07 15:25:34,463 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 1 | session_2: Score 0.948
# 2023-11-07 15:25:34,584 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 1 | session_0: Score 0.864
# 2023-11-07 15:25:34,696 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 1 | session_1: Score 0.942
# 2023-11-07 15:25:34,817 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 1 | session_2: Score 0.984
# 2023-11-07 15:25:35,301 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 1 | session_0: Score 0.855
# 2023-11-07 15:25:35,831 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 1 | session_1: Score 0.953
# 2023-11-07 15:25:36,366 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 1 | session_2: Score 0.954
# 2023-11-07 15:25:36,501 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 1 | session_0: Score 0.856
# 2023-11-07 15:25:36,635 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 1 | session_1: Score 0.782
# 2023-11-07 15:25:36,787 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 1 | session_2: Score 0.940
# Zhou 2016-CrossSession:  33%|███████████████████████████████████▎                                                                      | 1/3 [00:06<00:13,  6.70s/it]/opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# 2023-11-07 15:25:38,647 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 2 | session_0: Score 0.682
# 2023-11-07 15:25:38,813 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 2 | session_1: Score 0.574
# 2023-11-07 15:25:38,977 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 2 | session_2: Score 0.468
# 2023-11-07 15:25:39,442 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 2 | session_0: Score 0.904
# 2023-11-07 15:25:39,931 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 2 | session_1: Score 0.735
# 2023-11-07 15:25:40,396 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 2 | session_2: Score 0.924
# 2023-11-07 15:25:40,508 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 2 | session_0: Score 0.900
# 2023-11-07 15:25:40,617 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 2 | session_1: Score 0.786
# 2023-11-07 15:25:40,728 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 2 | session_2: Score 0.929
# 2023-11-07 15:25:41,184 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 2 | session_0: Score 0.910
# 2023-11-07 15:25:41,666 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 2 | session_1: Score 0.750
# 2023-11-07 15:25:42,125 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 2 | session_2: Score 0.925
# 2023-11-07 15:25:42,252 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 2 | session_0: Score 0.687
# 2023-11-07 15:25:42,376 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 2 | session_1: Score 0.658
# 2023-11-07 15:25:42,501 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 2 | session_2: Score 0.798
# Zhou 2016-CrossSession:  67%|██████████████████████████████████████████████████████████████████████▋                                   | 2/3 [00:12<00:06,  6.12s/it]/opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning:   Could not parse meas date from the header. Setting to None.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/datasets/Zhou2016.py:111: RuntimeWarning: Could not define the number of bytes automatically. Defaulting to 2.
#   raw = read_raw_cnt(fname, preload=True, eog=["VEOU", "VEOL"])
# 2023-11-07 15:25:44,455 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 3 | session_0: Score 0.957
# 2023-11-07 15:25:44,612 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 3 | session_1: Score 0.949
# 2023-11-07 15:25:44,773 INFO MainThread moabb.evaluations.base CSP+optSVM | Zhou 2016 | 3 | session_2: Score 0.916
# 2023-11-07 15:25:45,258 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 3 | session_0: Score 0.992
# 2023-11-07 15:25:45,755 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 3 | session_1: Score 0.986
# 2023-11-07 15:25:46,236 INFO MainThread moabb.evaluations.base CSP+LDA | Zhou 2016 | 3 | session_2: Score 0.968
# 2023-11-07 15:25:46,339 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 3 | session_0: Score 0.992
# 2023-11-07 15:25:46,441 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 3 | session_1: Score 0.969
# 2023-11-07 15:25:46,552 INFO MainThread moabb.evaluations.base RG+LR | Zhou 2016 | 3 | session_2: Score 0.988
# 2023-11-07 15:25:47,031 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 3 | session_0: Score 0.989
# 2023-11-07 15:25:47,515 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 3 | session_1: Score 0.984
# 2023-11-07 15:25:48,000 INFO MainThread moabb.evaluations.base CSP+LR | Zhou 2016 | 3 | session_2: Score 0.981
# 2023-11-07 15:25:48,122 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 3 | session_0: Score 0.920
# 2023-11-07 15:25:48,240 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 3 | session_1: Score 0.927
# 2023-11-07 15:25:48,366 INFO MainThread moabb.evaluations.base RG+LDA | Zhou 2016 | 3 | session_2: Score 0.933
# Zhou 2016-CrossSession: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:18<00:00,  6.09s/it]

# %%
sns.catplot(
    data=results,
    x="session",
    y="score",
    hue="subject",
    col="dataset",
    kind="bar",
    palette="viridis",
)
plt.show()
# Out:
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fig = moabb_plt.score_plot(results)
plt.show()
# Out:
# 2023-09-27 17:38:30,575 WARNING MainThread moabb.analysis.plotting Dataset names are too similar, turning off name shortening
# /opt/anaconda3/envs/M2-MVA_MEEG_hands-on/lib/python3.10/site-packages/moabb/analysis/plotting.py:59: UserWarning: The palette list has more values (6) than needed (5), which may not be intended.
#   sea.stripplot(

# %%
stats = compute_dataset_statistics(results)
P, T = find_significant_differences(stats)
moabb_plt.summary_plot(P, T)
plt.show()

# %%
fig = moabb_plt.meta_analysis_plot(stats, "CSP+LDA", "RG+LR")
plt.show()
